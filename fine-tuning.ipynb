# %%
import sys
import shutil
import os
import logging
from dotenv import load_dotenv
from langchain_community.document_loaders import GithubFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import Chroma

# %%
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)

# %%
def load_documents(repository: str) -> list[Document]:
    """Loads documents from the specified repository."""
    logging.info(f"Loading documents from repository: {repository}")
    # if not os.path.exists(repository):
    #     raise FileNotFoundError(f"repository not found: {repository}")
    # loader = DirectoryLoader(repository, glob="**/*.md")

    loader = GithubFileLoader(
        repo="nudgenow/nudge-devdocs",
        branch="prod_main",
        file_filter=lambda file_path: file_path.endswith(
            ".md") and file_path.startswith("docs/"),
        directory=["docs/"],
        access_token="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",
    )

    documents = loader.load()
    
    return documents

documents: list[Document] = load_documents("docs")

# %%
import json

# %%
for doc in documents[:5]:
    print(json.dumps(doc.metadata, indent=2))
# Out:
# {
#   "path": "docs/01-getting-started/01-account-setup.md",
#   "sha": "3fff097133588d5aca032d0d6a2a2a31ed785aa9",
#   "source": "https://api.github.com/nudgenow/nudge-devdocs/blob/prod_main/docs/01-getting-started/01-account-setup.md"
# }
# {
#   "path": "docs/01-getting-started/02-invite-a-team-member.md",
#   "sha": "af74f74b000454e87bb71b2d09dc151ddc8171d0",
#   "source": "https://api.github.com/nudgenow/nudge-devdocs/blob/prod_main/docs/01-getting-started/02-invite-a-team-member.md"
# }
# {
#   "path": "docs/01-getting-started/03-finding-your-api-keys.md",
#   "sha": "172982dfe38301a35e4e785ec5abb1ddbf90d3af",
#   "source": "https://api.github.com/nudgenow/nudge-devdocs/blob/prod_main/docs/01-getting-started/03-finding-your-api-keys.md"
# }
# {
#   "path": "docs/02-core-concepts/01-events.md",
#   "sha": "166e8a49469abeaa724d39a2f2c805e970948302",
#   "source": "https://api.github.com/nudgenow/nudge-devdocs/blob/prod_main/docs/02-core-concepts/01-events.md"
# }
# {
#   "path": "docs/02-core-concepts/02-users.md",
#   "sha": "e6783253e3176787ad32e16b887b28c98b5fddf4",
#   "source": "https://api.github.com/nudgenow/nudge-devdocs/blob/prod_main/docs/02-core-concepts/02-users.md"
# }

# %%
BASE_URL = "https://docs.nudgenow.com/"

# %%
# Process all documents and transform paths to web URLs
import re
import os

for doc in documents:
    original_path = doc.metadata['path'][5:]
    print(f"Original path: {original_path}")
    
    # Split the path into components
    path_parts = original_path.split('/')
    
    # Clean each component by removing the numbering prefix
    cleaned_parts = [re.sub(r'^\d+[\-\.]', '', part) for part in path_parts]
    
    # Reassemble the path
    cleaned_path = '/'.join(cleaned_parts)

    # Replace spaces with underscores
    cleaned_path = cleaned_path.replace(' ', '%20')
    
    # Create web URL (remove .md extension)
    web_path = os.path.splitext(cleaned_path)[0]
    web_url = f"{BASE_URL}{web_path}"
    
    print(f"Cleaned path: {cleaned_path}")
    print(f"Web URL: {web_url}\n")

    # Update the document metadata with the new web URL
    doc.metadata['path_'] = web_url
# Out:
# Original path: 01-getting-started/01-account-setup.md
# Cleaned path: getting-started/account-setup.md
# Web URL: https://docs.nudgenow.com/getting-started/account-setup
#
# Original path: 01-getting-started/02-invite-a-team-member.md
# Cleaned path: getting-started/invite-a-team-member.md
# Web URL: https://docs.nudgenow.com/getting-started/invite-a-team-member
#
# Original path: 01-getting-started/03-finding-your-api-keys.md
# Cleaned path: getting-started/finding-your-api-keys.md
# Web URL: https://docs.nudgenow.com/getting-started/finding-your-api-keys
#
# Original path: 02-core-concepts/01-events.md
# Cleaned path: core-concepts/events.md
# Web URL: https://docs.nudgenow.com/core-concepts/events
#
# Original path: 02-core-concepts/02-users.md
# Cleaned path: core-concepts/users.md
# Web URL: https://docs.nudgenow.com/core-concepts/users
#
# Original path: 02-core-concepts/03-cohorts.md
# Cleaned path: core-concepts/cohorts.md
# Web URL: https://docs.nudgenow.com/core-concepts/cohorts
#
# Original path: 02-core-concepts/04-pages.md
# Cleaned path: core-concepts/pages.md
# Web URL: https://docs.nudgenow.com/core-concepts/pages
#
# Original path: 02-core-concepts/05-rewards.md
# Cleaned path: core-concepts/rewards.md
# Web URL: https://docs.nudgenow.com/core-concepts/rewards
#
# Original path: 02-core-concepts/06-campaigns.md
# Cleaned path: core-concepts/campaigns.md
# Web URL: https://docs.nudgenow.com/core-concepts/campaigns
#
# Original path: 03-quickstart/banner-integration.md
# Cleaned path: quickstart/banner-integration.md
# Web URL: https://docs.nudgenow.com/quickstart/banner-integration
#
# Original path: 03-quickstart/basic-integration.md
# Cleaned path: quickstart/basic-integration.md
# Web URL: https://docs.nudgenow.com/quickstart/basic-integration
#
# Original path: 03-quickstart/stories-integration.md
# Cleaned path: quickstart/stories-integration.md
# Web URL: https://docs.nudgenow.com/quickstart/stories-integration
#
# Original path: 04-platform/01-android/01-installation-android.md
# Cleaned path: platform/android/installation-android.md
# Web URL: https://docs.nudgenow.com/platform/android/installation-android
#
# Original path: 04-platform/01-android/02-identifying-users-android.md
# Cleaned path: platform/android/identifying-users-android.md
# Web URL: https://docs.nudgenow.com/platform/android/identifying-users-android
#
# Original path: 04-platform/01-android/03-tacking-events-android.md
# Cleaned path: platform/android/tacking-events-android.md
# Web URL: https://docs.nudgenow.com/platform/android/tacking-events-android
#
# Original path: 04-platform/01-android/04-Tracking Widgets/01-widget-tracking.md
# Cleaned path: platform/android/Tracking%20Widgets/widget-tracking.md
# Web URL: https://docs.nudgenow.com/platform/android/Tracking%20Widgets/widget-tracking
#
# Original path: 04-platform/01-android/04-Tracking Widgets/02-page-tracking.md
# Cleaned path: platform/android/Tracking%20Widgets/page-tracking.md
# Web URL: https://docs.nudgenow.com/platform/android/Tracking%20Widgets/page-tracking
#
# Original path: 04-platform/01-android/05-Embedding Widgets/01-Banners.md
# Cleaned path: platform/android/Embedding%20Widgets/Banners.md
# Web URL: https://docs.nudgenow.com/platform/android/Embedding%20Widgets/Banners
#
# Original path: 04-platform/01-android/05-Embedding Widgets/02-Stories.md
# Cleaned path: platform/android/Embedding%20Widgets/Stories.md
# Web URL: https://docs.nudgenow.com/platform/android/Embedding%20Widgets/Stories
#
# Original path: 04-platform/01-android/06-Callbacks/01-corecallbacks.md
# Cleaned path: platform/android/Callbacks/corecallbacks.md
# Web URL: https://docs.nudgenow.com/platform/android/Callbacks/corecallbacks
#
# Original path: 04-platform/01-android/06-Callbacks/02-uicallbacks.md
# Cleaned path: platform/android/Callbacks/uicallbacks.md
# Web URL: https://docs.nudgenow.com/platform/android/Callbacks/uicallbacks
#
# Original path: 04-platform/02-iOS/01-installation-ios.md
# Cleaned path: platform/iOS/installation-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/installation-ios
#
# Original path: 04-platform/02-iOS/02-identifying-users-ios.md
# Cleaned path: platform/iOS/identifying-users-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/identifying-users-ios
#
# Original path: 04-platform/02-iOS/03-tacking-events-ios.md
# Cleaned path: platform/iOS/tacking-events-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/tacking-events-ios
#
# Original path: 04-platform/02-iOS/04-Tracking Widgets/04-tracking-widgets-ios.md
# Cleaned path: platform/iOS/Tracking%20Widgets/tracking-widgets-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Tracking%20Widgets/tracking-widgets-ios
#
# Original path: 04-platform/02-iOS/04-Tracking Widgets/05-tracking-pages-ios.md
# Cleaned path: platform/iOS/Tracking%20Widgets/tracking-pages-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Tracking%20Widgets/tracking-pages-ios
#
# Original path: 04-platform/02-iOS/05-Embedding Widgets/06-Banners.md
# Cleaned path: platform/iOS/Embedding%20Widgets/Banners.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Embedding%20Widgets/Banners
#
# Original path: 04-platform/02-iOS/05-Embedding Widgets/07-Stories.md
# Cleaned path: platform/iOS/Embedding%20Widgets/Stories.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Embedding%20Widgets/Stories
#
# Original path: 04-platform/02-iOS/06-Callbacks/01-corecallbacks.md
# Cleaned path: platform/iOS/Callbacks/corecallbacks.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Callbacks/corecallbacks
#
# Original path: 04-platform/02-iOS/06-Callbacks/02-uicallbacks.md
# Cleaned path: platform/iOS/Callbacks/uicallbacks.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Callbacks/uicallbacks
#
# Original path: 04-platform/03-flutter/01-installation-flutter.md
# Cleaned path: platform/flutter/installation-flutter.md
# Web URL: https://docs.nudgenow.com/platform/flutter/installation-flutter
#
# Original path: 04-platform/03-flutter/02-identifying-users-flutter.md
# Cleaned path: platform/flutter/identifying-users-flutter.md
# Web URL: https://docs.nudgenow.com/platform/flutter/identifying-users-flutter
#
# Original path: 04-platform/03-flutter/03-tracking-events-flutter.md
# Cleaned path: platform/flutter/tracking-events-flutter.md
# Web URL: https://docs.nudgenow.com/platform/flutter/tracking-events-flutter
#
# Original path: 04-platform/03-flutter/04-Tracking Widgets/04-tracking-widgets.md
# Cleaned path: platform/flutter/Tracking%20Widgets/tracking-widgets.md
# Web URL: https://docs.nudgenow.com/platform/flutter/Tracking%20Widgets/tracking-widgets
#
# Original path: 04-platform/03-flutter/04-Tracking Widgets/07-tracking-pages.md
# Cleaned path: platform/flutter/Tracking%20Widgets/tracking-pages.md
# Web URL: https://docs.nudgenow.com/platform/flutter/Tracking%20Widgets/tracking-pages
#
# Original path: 04-platform/03-flutter/05-Embedding Widgets/08-stories.md
# Cleaned path: platform/flutter/Embedding%20Widgets/stories.md
# Web URL: https://docs.nudgenow.com/platform/flutter/Embedding%20Widgets/stories
#
# Original path: 04-platform/03-flutter/05-Embedding Widgets/09-banners.md
# Cleaned path: platform/flutter/Embedding%20Widgets/banners.md
# Web URL: https://docs.nudgenow.com/platform/flutter/Embedding%20Widgets/banners
#
# Original path: 04-platform/03-flutter/06-callbacks-flutter.md
# Cleaned path: platform/flutter/callbacks-flutter.md
# Web URL: https://docs.nudgenow.com/platform/flutter/callbacks-flutter
#
# Original path: 04-platform/04-react-native/01-installation-react-native.md
# Cleaned path: platform/react-native/installation-react-native.md
# Web URL: https://docs.nudgenow.com/platform/react-native/installation-react-native
#
# Original path: 04-platform/04-react-native/02-identifying-users-react-native-sdk.md
# Cleaned path: platform/react-native/identifying-users-react-native-sdk.md
# Web URL: https://docs.nudgenow.com/platform/react-native/identifying-users-react-native-sdk
#
# Original path: 04-platform/04-react-native/03-tracking-events-react-native.md
# Cleaned path: platform/react-native/tracking-events-react-native.md
# Web URL: https://docs.nudgenow.com/platform/react-native/tracking-events-react-native
#
# Original path: 04-platform/04-react-native/04-Tracking Widgets/04-tracking-widgets.md
# Cleaned path: platform/react-native/Tracking%20Widgets/tracking-widgets.md
# Web URL: https://docs.nudgenow.com/platform/react-native/Tracking%20Widgets/tracking-widgets
#
# Original path: 04-platform/04-react-native/04-Tracking Widgets/07-tracking-pages.md
# Cleaned path: platform/react-native/Tracking%20Widgets/tracking-pages.md
# Web URL: https://docs.nudgenow.com/platform/react-native/Tracking%20Widgets/tracking-pages
#
# Original path: 04-platform/04-react-native/05-Embedding Widgets/08-stories.md
# Cleaned path: platform/react-native/Embedding%20Widgets/stories.md
# Web URL: https://docs.nudgenow.com/platform/react-native/Embedding%20Widgets/stories
#
# Original path: 04-platform/04-react-native/05-Embedding Widgets/09-banners.md
# Cleaned path: platform/react-native/Embedding%20Widgets/banners.md
# Web URL: https://docs.nudgenow.com/platform/react-native/Embedding%20Widgets/banners
#
# Original path: 04-platform/04-react-native/06-callbacks.md
# Cleaned path: platform/react-native/callbacks.md
# Web URL: https://docs.nudgenow.com/platform/react-native/callbacks
#
# Original path: 04-platform/05-web/01.installation-web-sdk.md
# Cleaned path: platform/web/installation-web-sdk.md
# Web URL: https://docs.nudgenow.com/platform/web/installation-web-sdk
#
# Original path: 04-platform/05-web/02-identifying-users-web.md
# Cleaned path: platform/web/identifying-users-web.md
# Web URL: https://docs.nudgenow.com/platform/web/identifying-users-web
#
# Original path: 04-platform/05-web/03-tracking-events-web.md
# Cleaned path: platform/web/tracking-events-web.md
# Web URL: https://docs.nudgenow.com/platform/web/tracking-events-web
#
# Original path: 04-platform/05-web/04-adding-stories-web.md
# Cleaned path: platform/web/adding-stories-web.md
# Web URL: https://docs.nudgenow.com/platform/web/adding-stories-web
#
# Original path: 06-integrations/07-google-tag-manager/01.set-up.md
# Cleaned path: integrations/google-tag-manager/set-up.md
# Web URL: https://docs.nudgenow.com/integrations/google-tag-manager/set-up
#
# Original path: 06-integrations/07-google-tag-manager/02-data-layer.md
# Cleaned path: integrations/google-tag-manager/data-layer.md
# Web URL: https://docs.nudgenow.com/integrations/google-tag-manager/data-layer
#
# Original path: 06-integrations/csv-import.md
# Cleaned path: integrations/csv-import.md
# Web URL: https://docs.nudgenow.com/integrations/csv-import
#
# Original path: 08-security/01-authentication.md
# Cleaned path: security/authentication.md
# Web URL: https://docs.nudgenow.com/security/authentication
#
# Original path: 08-security/04-data-privacy.md
# Cleaned path: security/data-privacy.md
# Web URL: https://docs.nudgenow.com/security/data-privacy
#
# Original path: 09-releasenotes.md
# Cleaned path: releasenotes.md
# Web URL: https://docs.nudgenow.com/releasenotes

# %%
for doc in documents:
    original_path = doc.metadata['source'].split("docs/")[-1]
    print(f"Original path: {original_path}")
    
    # Split the path into components
    path_parts = original_path.split('/')
    
    # Clean each component by removing the numbering prefix
    cleaned_parts = [re.sub(r'^\d+[\-\.]', '', part) for part in path_parts]
    
    # Reassemble the path
    cleaned_path = '/'.join(cleaned_parts)

    # Replace spaces with underscores
    cleaned_path = cleaned_path.replace(' ', '%20')
    
    # Create web URL (remove .md extension)
    web_path = os.path.splitext(cleaned_path)[0]
    web_url = f"{BASE_URL}{web_path}"
    
    print(f"Cleaned path: {cleaned_path}")
    print(f"Web URL: {web_url}\n")

    # Update the document metadata with the new web URL
    doc.metadata['source'] = web_url
    doc.metadata['path'] = web_url
# Out:
# Original path: 01-getting-started/01-account-setup.md
# Cleaned path: getting-started/account-setup.md
# Web URL: https://docs.nudgenow.com/getting-started/account-setup
#
# Original path: 01-getting-started/02-invite-a-team-member.md
# Cleaned path: getting-started/invite-a-team-member.md
# Web URL: https://docs.nudgenow.com/getting-started/invite-a-team-member
#
# Original path: 01-getting-started/03-finding-your-api-keys.md
# Cleaned path: getting-started/finding-your-api-keys.md
# Web URL: https://docs.nudgenow.com/getting-started/finding-your-api-keys
#
# Original path: 02-core-concepts/01-events.md
# Cleaned path: core-concepts/events.md
# Web URL: https://docs.nudgenow.com/core-concepts/events
#
# Original path: 02-core-concepts/02-users.md
# Cleaned path: core-concepts/users.md
# Web URL: https://docs.nudgenow.com/core-concepts/users
#
# Original path: 02-core-concepts/03-cohorts.md
# Cleaned path: core-concepts/cohorts.md
# Web URL: https://docs.nudgenow.com/core-concepts/cohorts
#
# Original path: 02-core-concepts/04-pages.md
# Cleaned path: core-concepts/pages.md
# Web URL: https://docs.nudgenow.com/core-concepts/pages
#
# Original path: 02-core-concepts/05-rewards.md
# Cleaned path: core-concepts/rewards.md
# Web URL: https://docs.nudgenow.com/core-concepts/rewards
#
# Original path: 02-core-concepts/06-campaigns.md
# Cleaned path: core-concepts/campaigns.md
# Web URL: https://docs.nudgenow.com/core-concepts/campaigns
#
# Original path: 03-quickstart/banner-integration.md
# Cleaned path: quickstart/banner-integration.md
# Web URL: https://docs.nudgenow.com/quickstart/banner-integration
#
# Original path: 03-quickstart/basic-integration.md
# Cleaned path: quickstart/basic-integration.md
# Web URL: https://docs.nudgenow.com/quickstart/basic-integration
#
# Original path: 03-quickstart/stories-integration.md
# Cleaned path: quickstart/stories-integration.md
# Web URL: https://docs.nudgenow.com/quickstart/stories-integration
#
# Original path: 04-platform/01-android/01-installation-android.md
# Cleaned path: platform/android/installation-android.md
# Web URL: https://docs.nudgenow.com/platform/android/installation-android
#
# Original path: 04-platform/01-android/02-identifying-users-android.md
# Cleaned path: platform/android/identifying-users-android.md
# Web URL: https://docs.nudgenow.com/platform/android/identifying-users-android
#
# Original path: 04-platform/01-android/03-tacking-events-android.md
# Cleaned path: platform/android/tacking-events-android.md
# Web URL: https://docs.nudgenow.com/platform/android/tacking-events-android
#
# Original path: 04-platform/01-android/04-Tracking Widgets/01-widget-tracking.md
# Cleaned path: platform/android/Tracking%20Widgets/widget-tracking.md
# Web URL: https://docs.nudgenow.com/platform/android/Tracking%20Widgets/widget-tracking
#
# Original path: 04-platform/01-android/04-Tracking Widgets/02-page-tracking.md
# Cleaned path: platform/android/Tracking%20Widgets/page-tracking.md
# Web URL: https://docs.nudgenow.com/platform/android/Tracking%20Widgets/page-tracking
#
# Original path: 04-platform/01-android/05-Embedding Widgets/01-Banners.md
# Cleaned path: platform/android/Embedding%20Widgets/Banners.md
# Web URL: https://docs.nudgenow.com/platform/android/Embedding%20Widgets/Banners
#
# Original path: 04-platform/01-android/05-Embedding Widgets/02-Stories.md
# Cleaned path: platform/android/Embedding%20Widgets/Stories.md
# Web URL: https://docs.nudgenow.com/platform/android/Embedding%20Widgets/Stories
#
# Original path: 04-platform/01-android/06-Callbacks/01-corecallbacks.md
# Cleaned path: platform/android/Callbacks/corecallbacks.md
# Web URL: https://docs.nudgenow.com/platform/android/Callbacks/corecallbacks
#
# Original path: 04-platform/01-android/06-Callbacks/02-uicallbacks.md
# Cleaned path: platform/android/Callbacks/uicallbacks.md
# Web URL: https://docs.nudgenow.com/platform/android/Callbacks/uicallbacks
#
# Original path: 04-platform/02-iOS/01-installation-ios.md
# Cleaned path: platform/iOS/installation-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/installation-ios
#
# Original path: 04-platform/02-iOS/02-identifying-users-ios.md
# Cleaned path: platform/iOS/identifying-users-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/identifying-users-ios
#
# Original path: 04-platform/02-iOS/03-tacking-events-ios.md
# Cleaned path: platform/iOS/tacking-events-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/tacking-events-ios
#
# Original path: 04-platform/02-iOS/04-Tracking Widgets/04-tracking-widgets-ios.md
# Cleaned path: platform/iOS/Tracking%20Widgets/tracking-widgets-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Tracking%20Widgets/tracking-widgets-ios
#
# Original path: 04-platform/02-iOS/04-Tracking Widgets/05-tracking-pages-ios.md
# Cleaned path: platform/iOS/Tracking%20Widgets/tracking-pages-ios.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Tracking%20Widgets/tracking-pages-ios
#
# Original path: 04-platform/02-iOS/05-Embedding Widgets/06-Banners.md
# Cleaned path: platform/iOS/Embedding%20Widgets/Banners.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Embedding%20Widgets/Banners
#
# Original path: 04-platform/02-iOS/05-Embedding Widgets/07-Stories.md
# Cleaned path: platform/iOS/Embedding%20Widgets/Stories.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Embedding%20Widgets/Stories
#
# Original path: 04-platform/02-iOS/06-Callbacks/01-corecallbacks.md
# Cleaned path: platform/iOS/Callbacks/corecallbacks.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Callbacks/corecallbacks
#
# Original path: 04-platform/02-iOS/06-Callbacks/02-uicallbacks.md
# Cleaned path: platform/iOS/Callbacks/uicallbacks.md
# Web URL: https://docs.nudgenow.com/platform/iOS/Callbacks/uicallbacks
#
# Original path: 04-platform/03-flutter/01-installation-flutter.md
# Cleaned path: platform/flutter/installation-flutter.md
# Web URL: https://docs.nudgenow.com/platform/flutter/installation-flutter
#
# Original path: 04-platform/03-flutter/02-identifying-users-flutter.md
# Cleaned path: platform/flutter/identifying-users-flutter.md
# Web URL: https://docs.nudgenow.com/platform/flutter/identifying-users-flutter
#
# Original path: 04-platform/03-flutter/03-tracking-events-flutter.md
# Cleaned path: platform/flutter/tracking-events-flutter.md
# Web URL: https://docs.nudgenow.com/platform/flutter/tracking-events-flutter
#
# Original path: 04-platform/03-flutter/04-Tracking Widgets/04-tracking-widgets.md
# Cleaned path: platform/flutter/Tracking%20Widgets/tracking-widgets.md
# Web URL: https://docs.nudgenow.com/platform/flutter/Tracking%20Widgets/tracking-widgets
#
# Original path: 04-platform/03-flutter/04-Tracking Widgets/07-tracking-pages.md
# Cleaned path: platform/flutter/Tracking%20Widgets/tracking-pages.md
# Web URL: https://docs.nudgenow.com/platform/flutter/Tracking%20Widgets/tracking-pages
#
# Original path: 04-platform/03-flutter/05-Embedding Widgets/08-stories.md
# Cleaned path: platform/flutter/Embedding%20Widgets/stories.md
# Web URL: https://docs.nudgenow.com/platform/flutter/Embedding%20Widgets/stories
#
# Original path: 04-platform/03-flutter/05-Embedding Widgets/09-banners.md
# Cleaned path: platform/flutter/Embedding%20Widgets/banners.md
# Web URL: https://docs.nudgenow.com/platform/flutter/Embedding%20Widgets/banners
#
# Original path: 04-platform/03-flutter/06-callbacks-flutter.md
# Cleaned path: platform/flutter/callbacks-flutter.md
# Web URL: https://docs.nudgenow.com/platform/flutter/callbacks-flutter
#
# Original path: 04-platform/04-react-native/01-installation-react-native.md
# Cleaned path: platform/react-native/installation-react-native.md
# Web URL: https://docs.nudgenow.com/platform/react-native/installation-react-native
#
# Original path: 04-platform/04-react-native/02-identifying-users-react-native-sdk.md
# Cleaned path: platform/react-native/identifying-users-react-native-sdk.md
# Web URL: https://docs.nudgenow.com/platform/react-native/identifying-users-react-native-sdk
#
# Original path: 04-platform/04-react-native/03-tracking-events-react-native.md
# Cleaned path: platform/react-native/tracking-events-react-native.md
# Web URL: https://docs.nudgenow.com/platform/react-native/tracking-events-react-native
#
# Original path: 04-platform/04-react-native/04-Tracking Widgets/04-tracking-widgets.md
# Cleaned path: platform/react-native/Tracking%20Widgets/tracking-widgets.md
# Web URL: https://docs.nudgenow.com/platform/react-native/Tracking%20Widgets/tracking-widgets
#
# Original path: 04-platform/04-react-native/04-Tracking Widgets/07-tracking-pages.md
# Cleaned path: platform/react-native/Tracking%20Widgets/tracking-pages.md
# Web URL: https://docs.nudgenow.com/platform/react-native/Tracking%20Widgets/tracking-pages
#
# Original path: 04-platform/04-react-native/05-Embedding Widgets/08-stories.md
# Cleaned path: platform/react-native/Embedding%20Widgets/stories.md
# Web URL: https://docs.nudgenow.com/platform/react-native/Embedding%20Widgets/stories
#
# Original path: 04-platform/04-react-native/05-Embedding Widgets/09-banners.md
# Cleaned path: platform/react-native/Embedding%20Widgets/banners.md
# Web URL: https://docs.nudgenow.com/platform/react-native/Embedding%20Widgets/banners
#
# Original path: 04-platform/04-react-native/06-callbacks.md
# Cleaned path: platform/react-native/callbacks.md
# Web URL: https://docs.nudgenow.com/platform/react-native/callbacks
#
# Original path: 04-platform/05-web/01.installation-web-sdk.md
# Cleaned path: platform/web/installation-web-sdk.md
# Web URL: https://docs.nudgenow.com/platform/web/installation-web-sdk
#
# Original path: 04-platform/05-web/02-identifying-users-web.md
# Cleaned path: platform/web/identifying-users-web.md
# Web URL: https://docs.nudgenow.com/platform/web/identifying-users-web
#
# Original path: 04-platform/05-web/03-tracking-events-web.md
# Cleaned path: platform/web/tracking-events-web.md
# Web URL: https://docs.nudgenow.com/platform/web/tracking-events-web
#
# Original path: 04-platform/05-web/04-adding-stories-web.md
# Cleaned path: platform/web/adding-stories-web.md
# Web URL: https://docs.nudgenow.com/platform/web/adding-stories-web
#
# Original path: 06-integrations/07-google-tag-manager/01.set-up.md
# Cleaned path: integrations/google-tag-manager/set-up.md
# Web URL: https://docs.nudgenow.com/integrations/google-tag-manager/set-up
#
# Original path: 06-integrations/07-google-tag-manager/02-data-layer.md
# Cleaned path: integrations/google-tag-manager/data-layer.md
# Web URL: https://docs.nudgenow.com/integrations/google-tag-manager/data-layer
#
# Original path: 06-integrations/csv-import.md
# Cleaned path: integrations/csv-import.md
# Web URL: https://docs.nudgenow.com/integrations/csv-import
#
# Original path: 08-security/01-authentication.md
# Cleaned path: security/authentication.md
# Web URL: https://docs.nudgenow.com/security/authentication
#
# Original path: 08-security/04-data-privacy.md
# Cleaned path: security/data-privacy.md
# Web URL: https://docs.nudgenow.com/security/data-privacy
#
# Original path: 09-releasenotes.md
# Cleaned path: releasenotes.md
# Web URL: https://docs.nudgenow.com/releasenotes

# %%
for doc in documents[:5]:
    filename = os.path.basename(doc.metadata["source"])
    import re
    clean_filename = re.sub(r'^\d+\-', '', filename)
            
    if "title" not in doc.metadata:
        clean_title = os.path.splitext(clean_filename)[0].replace('-', ' ').title()

    print(f"Cleaned title: {clean_title}")
    # doc.metadata["title"] = clean_title
# Out:
# Cleaned title: Account Setup
# Cleaned title: Invite A Team Member
# Cleaned title: Finding Your Api Keys
# Cleaned title: Events
# Cleaned title: Users
